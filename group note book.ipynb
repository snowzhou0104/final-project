# %% [markdown]
# ## Introduction

# %% [markdown]
# This project is mainly used to find the best neighborhood in Pittsburgh. When we're looking for data, we're not looking at the infrastructure of the community itself. We think more about which neighborhood is best from a family's perspective. The reason for our choice is that every family has its own children, and the education and growth of children are closely related to the environment. We hope that a good community not only has good facilities but also a good environment to help children grow up. The three data points we chose were safety, arts, and entertainment. Each of these items is vital for families and children.

# %% [markdown]
# **public arts**
#
# I choose public arts as the main datasheet to analyze the best neighborhood.
#
# The main reason why I choose this set of data is that its data covers all neighborhoods and was released in 2021. In addition, I think public arts can reflect the overall cultural level and accomplishment of a neighborhood. The better the area is, the higher the demand for art is.
#
# I came up with the data that the Central Business District is the neighborhood with the most pubic art. Meanwhile, I found that Squirrel Hill South and Allegheny Center both have more than 10 public art.
#
# **Arrest**
#
# We chose to do analyze arrests in each neighborbood to determine whether it is a safe environment for both adults and children. To do this, I counted the amount of times a neighborhood was mentioned and which ever had the lowest number of arrests would be deemed as the safest area.
#
# **playgrounds**
#
# Our assignment is to determine the best neighborhood in Oakland. To help determine this, my data is about the amount of playground eqiupment in each of the different neighborhoods. The submetric I'm using is that the more playground equipment a neighborhood has, the more friendly it is for children as it provides Children a way to get outside and play while minimizing danger. Though playgrounds are not the most necessary form of infrastructure, they help to determine the amount of thought put into making the neighborhood better for its inhabitants and

# %% [markdown]
# ## Metric
#
# We use 3 data sheets: public arts, arrest, and playgrounds.
#
# For all of data, we only use "neighborhood" column to counts how many public arts/ playgrounds/arrest they have for each neighborhood.

# %% [markdown]
# ## The Best Neighborhood

# %% [markdown]
# **public arts**

# %%
import pandas as pd

# %% [markdown]
# This is an example for public arts data sheet. The table below is the first ten lines of the datasheet I selected.

# %%
import pandas as pd
# %matplotlib inline

art = pd.read_csv("public_arts.csv", sep = ',')
art.head(10)
# Out:
#            id  name                              title  \
# 0   812728309  1001              Oakwood Road Monument
# 1   188255168  1002  Rooster Waiting For The Streetcar
# 2  2032091917   129        Middle East Memorial Plaque
# 3  1447629273   143                           L'Enfant
# 4  1935017944   148      Veterans Memorial (Brookline)
# 5   752311791   153         Oakley Street Mosaic Steps
# 6   915929762   156                   Windows of Light
# 7   275033545   157                     Time Travelers
# 8   687548560   159               Untitled (Ben Grubb)
# 9  1980433881   161                              Caves
#
#                              artist_name                     art_type  \
# 0                                    NaN                          NaN
# 1                            James Simon  Modern and Contemporary Art
# 2                                    NaN                War Memorials
# 3                      Paul Roger-Bloche                 Historic Art
# ...

# %% [markdown]
# The way I primarily chose to count is according to "neighbrhood." This table shows all public arts exhibitions, but the data I need is the specific number of publc arts per neighborhood.

# %% [markdown]
# we only focus on the top 3 neighborhood to get which is the best neighborhood

# %%
art["neighborhood"].value_counts()
# Out:
# Central Business District    27
# Squirrel Hill South          20
# Allegheny Center             18
# Highland Park                10
# South Side Flats              9
# North Shore                   8
# Beechview                     7
# Shadyside                     6
# Central Oakland               5
# Lower Lawrenceville           5
# Brighton Heights              5
# Spring Hill-City View         4
# Crawford-Roberts              3
# Greenfield                    3
# Elliott                       3
# Beltzhoover                   3
# Hazelwood                     3
# South Side Slopes             3
# Duquesne Heights              3
# Point Breeze                  3
# Garfield                      2
# Upper Hill                    2
# Central Lawrenceville         2
# Spring Garden                 2
# Mount Washington              2
# Allentown                     2
# Strip District                2
# Lincoln-Lemington-Belmar      2
# Squirrel Hill North           2
# ...

# %% [markdown]
# I use a bar chart to show all the data.

# %%
art["neighborhood"].value_counts().plot(kind='bar', rot=90, figsize = (20, 25))

# %% [markdown]
# From the previous data and the viewable view, I think the Central Business District is the best neighborhood. This is because it has the largest number of public art in Pittsburgh -27. Meanwhile, I ranked the top three neighborhoods as Central Business District, Allegheny Center, and Squirrel Hill South.

# %% [markdown]
# **arrest**

# %% [markdown]
# This is an example of arrest data sheet

# %%
import pandas as ad
# %matplotlib inline
arrest = ad.read_csv("arrest.csv", sep = ',')
arrest.head(10)
# Out:
#         PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# 5  1974556  16144301  45.0      M    W  2016-08-15T13:30:00
# 6  1974628  16147655  29.0      M    W  2016-08-16T13:00:00
# 7  1974607  16146037  21.0      F    B  2016-08-16T04:25:00
# 8  1974643  16132537  17.0      M    B  2016-08-29T17:55:00
# 9  1974647  16138646  14.0      M    B  2016-08-23T13:36:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# ...

# %% [markdown]
# We use reverse order to decide which neighborhood is the best

# %%
arrest["INCIDENTNEIGHBORHOOD"].value_counts()
# Out:
# Central Business District    3794
# South Side Flats             3190
# Carrick                      2200
# East Allegheny               2018
# Homewood South               1945
#                              ...
# Ridgemont                      35
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %%
arrest["INCIDENTNEIGHBORHOOD"].value_counts().plot(kind='bar', rot=90, figsize = (20, 25))

# %% [markdown]
# **playgrounds**

# %% [markdown]
# This is an example of playgrounds data sheet

# %%
# %matplotlib inline
playgrounds = pd.read_csv("playgrounds.csv", sep = ',')
playgrounds.head(10)
# Out:
#            id                          name     equipment_type  manufacturer  \
# 0  1780722587          Able Long Playground   Play Area 2 to 5  Little Tykes
# 1   702514290         North Ave. Playground   Play Area 2 to 5     Playworld
# 2  1267038491  Vietnam Veteran's Playground              Slide  Little Tykes
# 3    14898932  Schenley Overlook Playground       Swing 2 Bays  Little Tykes
# 4   204832406  Schenley Overlook Playground              Slide  Little Tykes
# 5   788191865          Chartiers Playground       Swing 2 Bays  Little Tykes
# 6  1387089430          Chartiers Playground       Swing 2 Bays  Little Tykes
# 7  1838217886          Chartiers Playground   Play Area 2 to 5  Little Tykes
# 8  1315630398          Chartiers Playground  Play Area 5 to 12  Little Tykes
# 9  1603952265          Chartiers Playground              Whirl           NaN
#
#   safety_surface_type ada_accessible  street_number             street  \
# ...

# %% [markdown]
# We focus on the top 3 neighborhood to determine th best one

# %%
playgrounds["neighborhood"].value_counts()
# Out:
# Squirrel Hill South    32
# East Liberty           26
# Beechview              21
# Allegheny Center       15
# South Side Slopes      14
#                        ..
# Esplen                  2
# Central Oakland         2
# Westwood                2
# Strip District          1
# West Oakland            1
# Name: neighborhood, Length: 68, dtype: int64

# %%
playgrounds["neighborhood"].value_counts().plot(kind='bar', rot=90, figsize = (20, 25))

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Overall, we chose the Squirrel Hill South as the best nergiborhood for this projet. Based on the data we analysis, playgrounds data sheet shows that Squirrel Hill South contains the most quantity of playgroudns equipments. Public arts data sheet shows Squirrel Hill South is the best top three neighborhood where contains the most quantity of public arts exihibitions. Even though Squirrel Hill South is located in middle for arrest datasheet. However, the quantity of arrest is fairly normal.
#
# The reaosn why the quantity of arrest is larger than we thought in Squirrel Hill South is that the area is quite large. But it is different size of area for different neighborhood.

# %% [markdown]
# **public arts**
#
# My favorite neighborhood is Squirrel Hill South. Squirrel Hill South is still in the top three, though not as the data suggest. So, I think I can still live with that.
#
# The reasons for this result are various. First of all, this ranking only depends on the number of public art, which is not a comprehensive result. I think Squirrel Hill South is the best neighborhood because of its convenient transportation and comprehensive surrounding facilities. There are many factors involved. At the same time, the neighborhood I know are not complete with data sorting, so there may be some deviation.
#
# **arrest**
#
# Seeing that this code has shown that the township, Mt. Oliver Neighborhood, has the least amount of crimes that take place here, we can say that it is a safe place for families. We are able to come to this conclusion because my bar graph has shown that the township with the lowest bar is the place with the lowest crime rate in Pittsburgh.
#
#
# **playgrounds**
#
# According to the data and the submetric we used to evaluate it, the best neighborhood would be Squirrel Hill South as it contains the most playground equipment with 16. After that the best would be East Liberty, with 13 then Beechview/South Oakland which are tied with 9. my This somewhat matches up with my personal views of the neighborhoods as my personal beliefs on the best would be beechview/Squirrel Hill.
